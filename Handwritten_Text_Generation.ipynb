# %%
import zipfile
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
zip_path = "HKR_Dataset-master.zip"
extract_path = "HKR_Dataset"

# %%
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
for root, dirs, files in os.walk(extract_path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# HKR_Dataset\HKR_Dataset-master\LICENSE.CC-BY-NC-ND-4.0
# HKR_Dataset\HKR_Dataset-master\README.md
# HKR_Dataset\HKR_Dataset-master\Application_Form\Application_Form_for_HKR.doc
# HKR_Dataset\HKR_Dataset-master\images\0_10_23.jpg
# HKR_Dataset\HKR_Dataset-master\images\0_10_30.jpg
# HKR_Dataset\HKR_Dataset-master\images\0_10_615_.jpg
# HKR_Dataset\HKR_Dataset-master\images\0_11_55.jpg
# HKR_Dataset\HKR_Dataset-master\images\0_13_55.jpg
# HKR_Dataset\HKR_Dataset-master\images\0_13_614.jpg
# HKR_Dataset\HKR_Dataset-master\images\0_9_16.jpg
# HKR_Dataset\HKR_Dataset-master\images\0_9_623.jpg
# HKR_Dataset\HKR_Dataset-master\images\sample1.png
# HKR_Dataset\HKR_Dataset-master\images\sample2.png

# %%
sample_img_path = os.path.join("HKR_Dataset", "HKR_Dataset-master", "images", "sample1.png")

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open(sample_img_path)
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.title("HKR Sample Handwritten Image")
plt.show()

# %%
# !pip install pytesseract

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
text = pytesseract.image_to_string(img, lang='eng')
print("OCR Output:\n")
print(text)
# Out:
# OCR Output:
#
# én crenbw,
# gouro, Womro. | Kyza? Sauem?
# Zi KK
# é,
# Ham 9To Fleer He y3HaTb.
# OH yBUeN BOs-
# Ka,
# ag
# UHLy. ; MATB...
# : {UCL Za8
# 3apocmax
# Oua jexKasa B P
# Qua fp TIOJIbIHH,
# u OcKaJIMB
# OrkuHysB Jaribl
# ey, , macTb.
# MEE nC
# U
# llepexBa4yeHHOrO
# MS rapa u TIBIA
# : ONL
# rb,
# Tom4ukaMu rycTaa, CIOBHO
# KPOBb, : bee rae rpa3b.
# Kem? Kem? 9 OxoTrHH4buMu
# Bomkom? P TicaMu? er
# AA ALE AE SE,
# ___ | en oe ee
# v LX MAXKAT VO
# HW Bopya,. coca-
# aH
#
# HermOaTJIMByt!0
# MaTb.
# TomogHpie BOJI-
# mo3aGbin,
# yatTa
# Kak  BylacTHO
# maxHeT
#
# Oun, mpywKaB- K MaMe, 2KaJHO
# WIHCb ; 9 iy LLY, TIMI
# Tycryro xov10- _—
# Terouly10 Q
# C raorKaMu B BXOUMIIA 2KarK-
# HUX A / ; qa MecTH.
# a ah
# Komy? JI1060- JImmp 6p HE
# ry
#
# My. IIPOCTUTb.
#
# y J X 47" cA“ AMOALY P
#
# 4, Ss,
# UY 6ynyT B  orgesbHo-
# MCTUTb cTH
# LAN
# RE,
#
# He secre. 4 A scrpeTatca —
# Alpyr apyry 6ynyT MCTHTD.
# VY uenopek m0-
#
# Et cBoeit Zoporoi.
# wen
# ...

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# ...

# %%
import cv2
import numpy as np

# %%
img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
gray = cv2.cvtColor(img_cv, cv2.COLOR_BGR2GRAY)

# %%
blur = cv2.GaussianBlur(gray, (5, 5), 0)
thresh = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 2)

# %%
processed_img = Image.fromarray(thresh)

# %%
plt.imshow(processed_img, cmap='gray')
plt.axis('off')
plt.title("Preprocessed for OCR")
plt.show()

# %%
print("OCR After Preprocessing:")
print(pytesseract.image_to_string(processed_img, lang='eng'))
# Out:
# OCR After Preprocessing:
# Bonuara ,
#
# IMO
#
# Cid,
# G £.
# Tonogubie Bon- nosa6eant
# yaTa LO Cae: f a ,
#
# IKAac: **
#
# ‘}..Cynetimenos. -
#
# Ilén aenosex. -
#
# Wonro, Horo. -
#
# B rycrok s10- . “OH Ht yBuen BOJI-
# mune _& Womoi to
# %,
# Bepuei, Bos- TouHee,
# 4HLY, (DY keke I, CKp MaTD.« Ie.
#
# gapocnax
# NONbIHH,
#
# Oua neKana B
#
# OCKaJINB
#
# " OG
#
# KPOBb
#
# P ; é oly.
# Kem? Kem? ,! OxoTrHH4bumMn
# Bonxom? Ticamu? 0 g 9,0 PIP
#
# XO LEK
# Cnenbim BOuI-
# waram 9TO He y3HaTb.
# CILRITAZ ESL v HLT] oa
#
# HerlogaTanBy!o
# Bonpuryro a ¥
# MaTb.
#
# BACTHO ‘sapocmAx
# naxHerT BG, | yxpor.
#
# Ounu, mpyoKas- K MaMe, 2KaHO
# HIHCb a TLMJIHT
# Tycryro xou0-
# neo ay 0 “pose.
# vil {yAO O20 ad ICLOLL
# on TOTKaMH B BXOAHIa 2Ka2K-
# Ha MeCTH.
# we Jlro60- JIumpb 6pr He
# MpOcTHuTs.
# Le
# br momen are
# MCTHTb cru
# ttt ,
#
# YW uenosex no-
#
# [ ODKIIL
# che pte ——
#
# i cBoeit. nOporon.
# wen p f .
# QAAPH OL
#
# Kyma?.. Sa-
# .4em?.. |
#
# Ham o9fTo He
# ysHarh.
#
# ...
